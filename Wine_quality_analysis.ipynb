# %% [markdown]
# ## import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Introduction of dataset

# %%
df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### data statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %% [markdown]
# Breakdown of each statistic:
#
# Count: Number of data points for each feature (all 1599).
#
# Mean: The average value for each feature.
#
# Standard Deviation (std): It measures the variability or spread in the data.
#
# Min: The minimum value observed for each feature.
#
# 25%, 50%, 75% (Quartiles):
#
#     25% (First Quartile): 25% of the data falls below this value.
#
#     50% (Median): 50% of the data falls below this value.
#
#     75% (Third Quartile): 75% of the data falls below this value.
#
# Max: The maximum value observed for each feature.

# %% [markdown]
# Feature statistics breakdown:
#
# 1. The median quality rating is 6, with most wines scoring between 5 and 6, on a scale from 3 to 8.
# 2. The average alcohol content is 10.42%, with a range from 8.4% to 14.9%.

# %% [markdown]
# ### NaN values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
def count_nan(df):
    # For each column in the dataset perform the isna() operation and summarize the missing samples
    for col in df.columns:
        # Calculate the number of missing values (isna().sum()) and the total percentage
        missing_count = df[col].isna().sum()
        missing_percentage = (missing_count / len(df)) * 100
        # Print the result with formatted string
        print(f"The column {col} is missing {missing_percentage:.2f}% of data!")



count_nan(df)
# Out:
# The column fixed acidity is missing 0.00% of data!
# The column volatile acidity is missing 0.00% of data!
# The column citric acid is missing 0.00% of data!
# The column residual sugar is missing 0.00% of data!
# The column chlorides is missing 0.00% of data!
# The column free sulfur dioxide is missing 0.00% of data!
# The column total sulfur dioxide is missing 0.00% of data!
# The column density is missing 0.00% of data!
# The column pH is missing 0.00% of data!
# The column sulphates is missing 0.00% of data!
# The column alcohol is missing 0.00% of data!
# The column quality is missing 0.00% of data!

# %% [markdown]
# The dataset does not contain any nan values.
#
# At below, I have commented out the code as the dataset dooes not include any nan value.

# %%
# 1. Extract all the samples that meet the criteria of isna()
# nan_samples = df[df.isna().any(axis=1)]

# 2. Get the indexes for these rows
# nan_indexes = nan_samples.index

# 3. Drop them from the dataframe
# df = df.drop(nan_indexes)

# Finally, let's rerun the count_nan function to examine our revised dataset
# count_nan(df)

# %% [markdown]
# ### Filtering & reindexing
# Here we are filtering the dataset by quality in ascending order and then reset the indexing

# %%
df = df.sort_values(by='quality', ascending=True)
df = df.reset_index(drop=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.1             0.875         0.05             5.7      0.082
# 1              10.4             0.440         0.42             1.5      0.145
# 2               8.3             1.020         0.02             3.4      0.084
# 3               6.8             0.815         0.00             1.2      0.267
# 4              11.6             0.580         0.66             2.2      0.074
# ...             ...               ...          ...             ...        ...
# 1594           10.7             0.350         0.53             2.6      0.070
# 1595            7.2             0.330         0.33             1.7      0.061
# 1596           10.0             0.260         0.54             1.9      0.083
# 1597            7.2             0.380         0.31             2.0      0.056
# 1598            7.4             0.360         0.30             1.8      0.074
#
# ...

# %% [markdown]
# ### Transforming Data

# %% [markdown]
# Normalization transforms the data so that all values in each column range between 0 and 1.
#
# This makes comparing features easier since they’re on the same scale.
#
# We do this by subtracting the minimum value from each data point and dividing by the range (maximum minus minimum). The idea is to make the data consistent across columns, which helps in analysis and machine learning.

# %%
def normalize_values(col_value, min_val, max_val):
    # Normalize the value between 0 and 1 using min-max scaling
    normalized_val = (col_value - min_val) / (max_val - min_val)
    return normalized_val

def main():
    for column in df.columns:
        # Calculate the minimum and maximum values for each column
        min_val = df[column].min()
        max_val = df[column].max()
        # Apply the normalization function to each column
        df[column] = df[column].apply(normalize_values, args=(min_val, max_val))

main()

# Display the statistical summary of the normalized dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        0.329171          0.279329     0.270976        0.112247
# std         0.154079          0.122644     0.194801        0.096570
# min         0.000000          0.000000     0.000000        0.000000
# 25%         0.221239          0.184932     0.090000        0.068493
# 50%         0.292035          0.273973     0.260000        0.089041
# 75%         0.407080          0.356164     0.420000        0.116438
# max         1.000000          1.000000     1.000000        1.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.125988             0.209506              0.142996     0.490211
# std       0.078573             0.147326              0.116238     0.138571
# ...

# %% [markdown]
# we could use this code also:
#
# def main():
#
#     df_normalized = (df - df.min()) / (df.max() - df.min())
#     return df_normalized
#
#
# df = main()
#
# df.describe()

# %% [markdown]
# ### Outlier
#
# Outliers are data points that significantly differ from the rest of the dataset. They can be much higher or lower than other observations.

# %%
import matplotlib.pyplot as plt

df.plot(
    kind='box', 
    subplots=True, 
    sharey=False, 
    figsize=(10, 6),
    
)

# Increase spacing between subplots
plt.subplots_adjust(wspace=0.3)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format for seaborn
df_melted = df.melt(var_name='Features', value_name='Values')

# Create a box plot using seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(x='Features', y='Values', data=df_melted)

# Rotate x-tick labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.title('Box Plot of Features with outliers')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()

# %% [markdown]
# # Statistical tool : The 5-number summary
#
# The 5-number summary is a valuable statistical tool for understanding data distribution and identifying outliers. It consists of five key values,
#
# 1. the minimum (smallest data point),
# 2. the first quartile 25% (Q1),
# 3. the median 50% (Q2 or the second quartile),
# 4. the third quartile 75% (Q3), and
# 5. the maximum (largest data point).
#
#
# ### To detect outliers
# we focus on the interquartile range (IQR)
#
# calculated as:
# IQR = Q3 - Q1
# This IQR represents the middle 50% of the data.
#
# Outliers are identified as values that fall significantly lower fence and higher fence.
#
# Lower fence = Q1 - 1.5 * IQR
# Higher fence = Q3 + 1.5 * IQR
#
# Essentially, the 5-number summary with IQR helps us pinpoint unusual data points that might deviate from the overall pattern and warrant closer investigation.
#
# [download.jpg](attachment:download.jpg)

# %%
# Calculate Q1 and Q3
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the outlier threshold (e.g., 1.5 times IQR)
outlier_threshold = 1.5

# Identify rows with outliers
outliers = ((df < (Q1 - outlier_threshold * IQR)) | (df > (Q3 + outlier_threshold * IQR))).any(axis=1)

# Remove outliers
df = df[~outliers]

# %%
# Melt the DataFrame to long format for seaborn
df_melted = df.melt(var_name='Features', value_name='Values')

# Create a box plot using seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(x='Features', y='Values', data=df_melted)

# Rotate x-tick labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.title('Box Plot of Features without outliers')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()
