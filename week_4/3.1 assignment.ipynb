# %% [markdown]
# ### 3.1 Assignment
#
# Implementing transmission (i.e the virus spreading)

# %%
import numpy as np 
import random

# %%
class Person:
    def __init__(self):
        self.recover_prob = 0.2
        self.die_prob = 0.05
        self.init_sick_prob = 0.1
        self.infect_others_prob = 0.05
        self.average_meetups = 10
        self.recovered = False
        self.dead = False
        self.sick = False
        
        self.init_sick_or_not()
        
    def init_sick_or_not(self):
        """When created each person starts as either sick or healthy"""
        prob = random.random()
        if prob <= self.init_sick_prob:
            # This should yield that about 10% of the people created are sick, the rest healthy
            self.sick = True
        else:
            self.sick = False
             
            
    def infect_others (self, population):
        person_encounters = random.sample(range(population.size), self.average_meetups)
        for person_id in person_encounters:
            self_person=population[person_id]
            prob = random.random()
            if prob<=self.infect_others_prob and self_person.dead==False and self_person.recovered==False:
                population[person_id].sick=True
    
    
     
    def day_passes(self, population, init_scenario):
        if self.sick==True:
            if init_scenario == False:
                self.infect_others(population)
    
     # person recover?
        prob = random.random()
        if prob <= self.recover_prob and self.sick == True:
            # Person has rehabilitated and is now healthy!
            self.sick = False
            self.recovered = True 
             
        
        # If person is still sick they might die
        prob = random.random()
        if prob <= self.die_prob and self.sick == True:
            self.dead = True
            self.sick = False

# %%
class Village:
    def __init__(self, init_population_size):
        self.population = np.empty(init_population_size, Person)
        self.generate_inhabitants()
    
    def generate_inhabitants(self):
        """Generates the population"""
        for i in range(self.population.size):
            self.population[i] = Person()
        
    def advance_days(self, init_scenario = False):
        """Counts the status of the citizens in the community"""
        people_sick = 0
        people_recovered = 0
        people_dead = 0
        for person in self.population:
            if person.sick == True:
                people_sick += 1
            elif person.recovered == True:
                people_recovered += 1
            elif person.dead == True:
                people_dead += 1
            
            person.day_passes(self.population, init_scenario)

        return people_sick, people_recovered, people_dead
    
    def start_simulation(self):
        """This function controls the simulation and what happends in a day"""
        current_day = 0
        
        people_sick, people_recovered, people_dead = self.advance_days(init_scenario = True)
        while people_sick != 0:
            print(f"By day {current_day} {people_sick} people are sick, {people_dead} are dead and {people_recovered} has recovered")
            current_day += 1
            people_sick, people_recovered, people_dead = self.advance_days()
        
        people_unaffected = self.population.size - (people_sick + people_recovered + people_dead)
        print(f"\nBy day {current_day} {people_sick} people are sick, {people_dead} are dead and {people_recovered} has recovered. {people_unaffected} people were never in contact with the virus")
        print("The village has recovered and the virus is eliminated!")

# %%
def main():
    pop_size = 1000
    village = Village(pop_size)
    village.start_simulation()

main()
# Out:
# By day 0 92 people are sick, 0 are dead and 0 has recovered
# By day 1 85 people are sick, 5 are dead and 25 has recovered
# By day 2 102 people are sick, 9 are dead and 39 has recovered
# By day 3 138 people are sick, 13 are dead and 56 has recovered
# By day 4 156 people are sick, 16 are dead and 87 has recovered
# By day 5 191 people are sick, 19 are dead and 124 has recovered
# By day 6 194 people are sick, 27 are dead and 162 has recovered
# By day 7 201 people are sick, 36 are dead and 202 has recovered
# By day 8 227 people are sick, 52 are dead and 241 has recovered
# By day 9 208 people are sick, 66 are dead and 285 has recovered
# By day 10 196 people are sick, 70 are dead and 339 has recovered
# By day 11 194 people are sick, 76 are dead and 382 has recovered
# By day 12 174 people are sick, 88 are dead and 423 has recovered
# By day 13 163 people are sick, 88 are dead and 462 has recovered
# By day 14 160 people are sick, 91 are dead and 487 has recovered
# By day 15 135 people are sick, 99 are dead and 524 has recovered
# By day 16 119 people are sick, 106 are dead and 550 has recovered
# By day 17 110 people are sick, 112 are dead and 568 has recovered
# By day 18 100 people are sick, 115 are dead and 583 has recovered
# By day 19 86 people are sick, 118 are dead and 603 has recovered
# By day 20 73 people are sick, 120 are dead and 620 has recovered
# By day 21 56 people are sick, 122 are dead and 639 has recovered
# By day 22 47 people are sick, 126 are dead and 652 has recovered
# By day 23 38 people are sick, 127 are dead and 662 has recovered
# By day 24 37 people are sick, 127 are dead and 668 has recovered
# By day 25 36 people are sick, 127 are dead and 674 has recovered
# By day 26 29 people are sick, 128 are dead and 681 has recovered
# By day 27 26 people are sick, 128 are dead and 686 has recovered
# By day 28 27 people are sick, 128 are dead and 687 has recovered
# By day 29 18 people are sick, 129 are dead and 696 has recovered
# By day 30 11 people are sick, 131 are dead and 701 has recovered
# By day 31 7 people are sick, 131 are dead and 706 has recovered
# By day 32 5 people are sick, 131 are dead and 708 has recovered
# By day 33 6 people are sick, 131 are dead and 708 has recovered
# By day 34 5 people are sick, 131 are dead and 709 has recovered
# By day 35 5 people are sick, 131 are dead and 709 has recovered
# By day 36 6 people are sick, 131 are dead and 709 has recovered
# By day 37 8 people are sick, 131 are dead and 709 has recovered
# By day 38 6 people are sick, 132 are dead and 710 has recovered
# By day 39 3 people are sick, 133 are dead and 712 has recovered
# By day 40 1 people are sick, 133 are dead and 714 has recovered
# By day 41 1 people are sick, 133 are dead and 714 has recovered
# By day 42 1 people are sick, 133 are dead and 714 has recovered
# By day 43 1 people are sick, 133 are dead and 714 has recovered
#
# By day 44 0 people are sick, 133 are dead and 715 has recovered. 152 people were never in contact with the virus
# The village has recovered and the virus is eliminated!
